# %% [markdown]
# #Logistic Regression model
# Has been created using help from ChatGPT [instance](https://chatgpt.com/share/1eb327f3-4c23-4ca5-8a33-03e96af3e039).
#
# Working on the iris dataset, picked up from[ Data Professor](https://raw.githubusercontent.com/dataprofessor/data/master/iris.csv).

# %% [markdown]
# #Data import

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/dataprofessor/data/master/iris.csv")
print(df)
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #Data prep

# %% [markdown]
# ##Split into X and y

# %%
y = df["Species"]
print(y)
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: Species, Length: 150, dtype: object

# %%
X = df.drop("Species", axis = 1)
print(X)
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ##Splitting into train and test dataset

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 100)

# %% [markdown]
# #Model creation, fitting and prediction

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
lr.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_lr_test_pred = lr.predict(X_test)

# %% [markdown]
# #Evaluating model performance

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

accuracy = accuracy_score(y_test, y_lr_test_pred)
confusion = confusion_matrix(y_test, y_lr_test_pred)
classification = classification_report(y_test, y_lr_test_pred)

print("Accuracy score :", accuracy)
print("Confusion Matrix :\n", confusion)
print("Classification report :\n", classification)
# Out:
# Accuracy score : 0.9666666666666667
# Confusion Matrix :
#  [[11  0  0]
#  [ 0  5  1]
#  [ 0  0 13]]
# Classification report :
#                precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        11
#   versicolor       1.00      0.83      0.91         6
#    virginica       0.93      1.00      0.96        13
#
#     accuracy                           0.97        30
#    macro avg       0.98      0.94      0.96        30
# weighted avg       0.97      0.97      0.97        30
